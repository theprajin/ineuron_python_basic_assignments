# %% [markdown]
# #### Q1) What are the differences between operators and values in the following?
# #### *
# #### 'hello,
# #### -87.8
# #### -
# #### /
# #### +
# #### 6

# %% [markdown]
# In the given above, the operators are: *, -, /, and + and
# the values are: 'hello', -87.8, and 6

# %% [markdown]
# #### Q2) What is the difference between string and variable?
# #### spam
# #### 'spam'

# %% [markdown]
# Here spam is a variable and 'spam' is a string.

# %% [markdown]
# #### Q3) Describe three different data forms.

# %% [markdown]
# Different data types in Python are integer, float, complex number, boolean, string, list, tuple, dictionary, and set.

# %% [markdown]
# ##### Q4) What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# Expression is made up of operands and operators that can be reduced to a result value.
# E.g: 1 + 2

# %% [markdown]
# #### Q5) In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?

# %% [markdown]
# Declaration is what assigns value to a variable and expression is what can be reduced to a resultant value. E.g x = 10 is a declaration and 4*5 is an expression.

# %% [markdown]
# #### Q6) After running the following code, what does the variable bacon contain?
# #### bacon = 22
# #### bacon + 1

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [markdown]
# the variable will still contain the value 22

# %%
bacon
# Out:
# 22

# %% [markdown]
# #### Q7) What should the values of the following two terms be?
# #### 'spam' + 'spamspam'
# #### 'spam' * 3

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [markdown]
# #### Q8) Why is it that eggs is a true variable name but 100 is not?

# %% [markdown]
# It is because the variable name in Python can only start with a letter or an underscore character but not with a number.

# %% [markdown]
# #### Q9) Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?

# %% [markdown]
# To convert a value to an integer, a floating-point number and a string we use int(), float() and str() functions respectively

# %% [markdown]
# #### Q10) What is the error caused by this expression? What would you do about it?
# #### 'I have eaten ' + 99 + ' burritos.'

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# To fix the above error, first we have convert the integer value 99 into a string value and then do the concatenation as below:

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
