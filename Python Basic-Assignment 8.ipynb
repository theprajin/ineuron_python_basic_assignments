# %% [markdown]
# ### 1. Is the Python Standard Library included with PyInputPlus?

# %% [markdown]
# No, Python Standard Library is not included with PyInputPlus. We need to install it separetely as it is a third-party library.

# %% [markdown]
# ### 2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?

# %% [markdown]
#  This optionally makes your code shorter to type: you can type pyip.inputStr() instead of
# pyinputplus.inputStr().

# %% [markdown]
# ### 3. How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# The inputInt() function returns an int value, while the inputFloat() function returns a float value. This is
# the difference between returning 4 and 4.0.

# %% [markdown]
# ### 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %% [markdown]
# Call pyip.inputint(min=0, max=99).

# %% [markdown]
# ### 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?

# %% [markdown]
# A list of regex strings that are either explicitly allowed or denied.

# %% [markdown]
# ### 6. If a blank input is entered three times, what does inputStr(limit=3) do?

# %% [markdown]
# The function will raise RetryLimitException.

# %% [markdown]
# ### 7. If blank input is entered three times, what does inputStr(limit=3, default='hello') do?

# %% [markdown]
# The function returns the value 'hello'.
